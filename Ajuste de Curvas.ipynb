# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [0,1,2,3]
f = [0,0,2,4]

# %%
plt.scatter(x, f)

# %%
A = np.array([[14,2],[2,2]])
C = np.array([[16],[4]]) #Matriz 2x1
B = np.linalg.inv(A)
D = np.dot(B,C) #a0 = 1 e a1 = 1

xx = []
ff = []

for j in range(0,200):
  i = 0.01*j
  xx.append(j)
  ff.append(x + np.sin(3*i*np.pi/2))

plt.scatter(x,f)
plt.plot(xx,ff)
